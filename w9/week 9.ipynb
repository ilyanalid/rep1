# %% [markdown]
# ## Итераторы, итерируемые объекты

# %% [markdown]
# **1.** (2) Реализуйте класс `BinTree` двоичного дерева, итерирование по которму происходит в порядке обхода в глубину.

# %%
class Node:
    def __init__(self, left=None, right=None, data=None):
        self.left = left
        self.right = right
        self.data = data

    def __str__(self):
        return str(self.data)

class Tree:
    
    def update_tree(self):
        self.dfs_iter = iter(self.InOrder())
    
    def __init__(self, expression):
        self.root = None
        self.add(expression)
        self.update_tree()
    
    def add(self, expression):
        token_list = list(''.join(expression))
        self.root = self._addToTree(token_list)
        self.update_tree()

    def _addToTree(self, token_list):
        if token_list:
            brackets = 0
            index_sym = 0
            for inx, sym in enumerate(token_list):
                if sym == '(': brackets += 1
                if sym == ')': brackets -= 1
                if (sym != '(') and (sym != ')'): index_sym = inx
                if (brackets == 0) and (sym != ')') and (sym != '('):
                    index_sym = inx
                    break
            return Node(self._addToTree(token_list[1:index_sym]),
                        self._addToTree(token_list[index_sym+2:-1]),
                        token_list[index_sym])

    def InOrder(self):
        return self._InOrder(self.root)

    def _InOrder(self, node):
        res = []
        if node:
            res = self._InOrder(node.left)
            res.append(node.data)
            res = res + self._InOrder(node.right)
        return res
    
    def __iter__(self):
        return self
    
    def __next__(self):
        return next(self.dfs_iter)


tree = Tree('((c)b(d))a(((g)f(h))e)')


print('Обратный обход')
for i in tree:
    print(i)

print(tree.InOrder())
# Out:
# Обратный обход
# c
# b
# d
# a
# g
# f
# h
# e
# ['c', 'b', 'd', 'a', 'g', 'f', 'h', 'e']

# %% [markdown]
# **2.** (3) Скачайте архив, и положите его в папку с неделей 9.
#
# Создаейте класс `TextLoader`, который принимает в инициализаторе адрес архива.
#
# Затем добейтесь от класса следующего поведения:
# - При инициализации объекта (т.е. в методе `__init__`) этот класс должен разархивировать архив в какую-либо папку (имя неважно);
# - Метод `__len__` должен возвращать количество текстов в папке;
# - Метод `__next__`, который позволяет итерироваться по распакованным текстам, должен возвращать объект файла (тот, что возвращает `open()`);
# - При итерировании возвращаются нормализованные тексты, т.е. приводятся к нижнему регистру и убираются знаки препинания.
#
# Обратите внимание, что метод `__len__` не должен считывать все файлы. Также нельзя читать все файлы за раз - нужно это делать по мере необходимости.

# %%
import zipfile
import os
import re
import pathlib

class TextLoader:
    def __init__(self,url):
        with zipfile.ZipFile('sample.zip','r') as zip_ref:
            zip_ref.extractall(url)
            
        self.path = pathlib.Path('sample')
        self.files = [x for x in list(self.path.glob('**/*')) if x.is_file()]
        self.iterable = iter(self.files)

    def __len__(self):
        return len(self.files)

    def __next__(self):
        file_path = next(self.iterable)
        
        with file_path.open('r', encoding='utf-8') as f:
            read_file = f.read()
            
        with file_path.open('w', encoding='utf-8') as f:
            normalize_file = self.normal(read_file)
            f.write(normalize_file)
        f= file_path.open('r', encoding='utf-8') 
        return f

    def __iter__(self):
        return self

    def normal(self,s):
        s = re.sub(r'[^\w\s]', ' ',s)
        s = s.lower()
        return s

address = '.'
end = TextLoader(address)

print(len(end))

for i in range(len(end)):
    try:
        a = next(end)
        print(a.read()[:100])
        print('----------------------')
    except StopIteration:
        print('finish')
# Out:
# 100
#   мам  пап  это мой жених сашка
# мама отводит дочку в сторонку
#   ты зачем этого алкаша привела
#
# ----------------------
# 22 	про анфиску
#
# есть у нас в детском саду одна манюня  анфиска  у нас
# шкафчики по соседству  ну  шк
# ----------------------
# после новогодних каникул первое  что мы увидели  войдя в раздевалку
# была анфиска  она стояла на сту
# ----------------------
# я вспомнил эту историю вчера  когда забирал шкета из садика
# группа под руководством преподавателя п
# ----------------------
# подходит маленький сын к отцу и спрашивает    пап  скажи  что такое политика    объясню тебе на прим
# ----------------------
# подходит маленький сын к отцу и спрашивает    пап  скажи  что такое политика    объясню тебе на прим
# ----------------------
# мама  папа и сынок едут в машине
#  папа  папа  а вот наша мама водит машину лучше тебя
#  хм  ну почем
# ----------------------
# брат приехал из деревни  распродает мебель связи с переездом  рассказал
# вчера приезжали покупатели
# ----------------------
# 28 	  вы как хотите  а я бегать пошел на лыжах    сказал папа и направился
# к двери
#   стоять  боятьс
# ----------------------
# муж с женой приходят ночью домой пьяные
# шумом будят малолетнюю дочку
# папаня пьяный в лом кидается к
# ----------------------
# берлога медведей  папа медведь читает газету  мама медведь готовит ужин  сынишка медвежонок играет
# ----------------------
# папа  мама и сын в зоопарке  сын видит слона и спрашивает маму
#   мама  а что это за штука у слона
#
# ----------------------
# вовочка прибегает домой на кухню  там мамочка его обед варит  он весело
# кричит ей
#   мамочка  мамочк
# ----------------------
# маленький цыганенок прибежал с улицы домой  а дома только папа сидит
#   пап  есть что покушать    сп
# ----------------------
# 34 	мyжик  m  звонит в кваpтиpy
# тpyбкy снимает маленькая девочка  мд
#   девочка  твоя мама дома
#
# ----------------------
# приходит маленький мальчик из школы и говорит маме
#   мам  у меня есть проблема  в школе ребята гово
# ----------------------
# 36 	мужик заходит в аптеку  просит презерватив
# продавщица
#   вам какой  белый  черный или с микки
# ----------------------
# мальчик у мамы в бане cпpашивает
#   мам  что это у тебя    и показывает пальчиком   вcе поняли куда
# ----------------------
# женился как то поручик ржевский на наташе ростовой  родилась у них двойня
# мальчик и девочка  проход
# ----------------------
# маленький сынулька просит отца летчика  который собирается на север
#   папа  папа  привези мне якуте
# ----------------------
# 40 	привела семья сыночка в зоопарк  папа  мама  пятилетний сын
# подходят к участку со слоном  папе
# ----------------------
# вовочка приходит из школы с испуганным видом и говорит
#   мама  папа  я думаю  сегодня вам не стоит
# ----------------------
# радостный сынишка вбегает на кухню после школы
#   мама  я писать научился  слово из трех букв написа
# ----------------------
# шеф себе секретаршу искал  по объявлению явилось чудесное создание  на все вопросы хлопало ресницами
# ----------------------
# один голубой pассказывает дpугому
#   вчеpа девушку видел   что то необыкновенное  личико   небесная
# ----------------------
# в нашей стране есть две системы   правоохранительная и здравоохранительная
# встреча с любой из них о
# ----------------------
# идёт мужик по пустыне  пить хочется  он
#   боже  я пить хочу
# тут откуда не возьмись появляется вода
# ----------------------
# шумная улица  по ней идет крутейная блондинка  из глубокого декольте торчит прекрасной формы грудь
# ----------------------
# вниманию пассажиров  рейс до красноярска задерживается до 23 х по техническим причинам  рейс до хаба
# ----------------------
# 49 	блондинки беседуют
#   а как ты думаешь  зачем на вертолете ставят такой большой пропеллер
#   ты
# ----------------------
# чем компьютер похож на мужчину
# 1  ткнешь пальцем   он и заведется
# 2  требует много примочек и игру
# ----------------------
# сидят на кухне две блондинки
# беседу ведут сурьёзую
#   а вот ты знаешь  куда электричество девается
# ----------------------
#   привет  солнышко  это папа  маме трубочку дашь  она рядом
#
#   неа  пап  не могу  она там наверху в
# ----------------------
# очень не люблю людей  которые лезут не в свое дело  на днях решила обрезать волосы  спонтанно  они б
# ----------------------
# моя мама   генератор идей с самого детства  мы жили на спуске  под склоном  когда маме было лет 5  о
# ----------------------
# дело было во времена дефицита  маме каким то чудом достался перед новым годом настоящий ананас  поск
# ----------------------
# все же читали про представления о русских девушках у иностранцев  я про русые волосы  заплетенные в
# ----------------------
# я страшно боюсь публичных выступлений  перед более чем одним человеком выступать не могу  а я   вока
# ----------------------
# я стала невольным свидетелем шикарного предложения руки и сердца  прогуливаясь по парку  увидела  ка
# ----------------------
# а у нас сегодня с двух до четырёх ночи были землетрясения  это странное ощущение  невероятная паника
# ----------------------
# звонит какой то мужик и обращается ко мне  как к сестре  я ему сказала  что он ошибся номером  а он
# ----------------------
# если бы не измена любимого парня  я бы так и не узнала  что я гениальный мститель  когда обо всём уз
# ----------------------
# когда мне было 6 лет  моя крестная мама решила взять меня с собой в церковь  вокруг стояло очень мно
# ----------------------
# в целом  мой отец был не идеальным человеком  он мог и напиться  и подраться  и матом кого нибудь по
# ----------------------
# когда устраивалась на работу  меня все предупреждали  что начальник неадекват и постоянно орёт  из з
# ----------------------
# я очень робкая и стеснительная девушка  и это мне очень сильно мешает по жизни  все любят этим польз
# ----------------------
# вам когда нибудь снились осознанные сны  скажу вам на своем опыте  это очень странно  мне снился кош
# ----------------------
#   а это что за развалина    спрашивал эдик
#        а это старый китежград    отвечал роман
#        т
# ----------------------
# хочу рассказать историю о моем путешествии в одиночку  может  пригодится кому то  кто хочет куда то
# ----------------------
#  что за тип    проявила я любопытство
#   кто его знает  пятый день мне глаза мозолит
#   он что  прес
# ----------------------
#   наталья николаевна  как ваш муж обычно отмечал дни рождения
#
#   особо никогда не праздновал  ему э
# ----------------------
#     я уже поняла  вы и директору сказали то же самое
#   и могу повторить    так же весело откликнулс
# ----------------------
#   какой дисциплинированный  не то что старший братец    сказала мама  но не сердито  а так  между пр
# ----------------------
#   ух  как вкусно    попробовала я
#
#   кушай    улыбнулась бабушка
#
#   а еще оле очень твои пирожки п
# ----------------------
#   оль  мы ж с тобой никогда не ссорились раньше
#   а я с тобой и не ссорилась    ответила я
#   ну и
# ----------------------
#   ответить    сказал я приборчику
#   витя  ты где
#
# я поднес приборчик поближе к уху и громко ответи
# ----------------------
#   женя    сказала она ласково    ты  конечно  любишь бабушку  но  согласись  она поступила не по сов
# ----------------------
# женька  вставай    сказала степаненко    третий раз уж пытаюсь разбудить тебя
#   а ты брось в кроват
# ----------------------
#   я не прячусь  я сам немного артист  я не хотел вам мешать  и вот я стоял и слушал
#          да  н
# ----------------------
#    это они на вокзал  на погрузку поехали     важно объяснил коля колокольчиков     я по их обмундир
# ----------------------
#   ты посмотри  как  собаки  ругаются     смутившись  но пытаясь улыбнуться  продолжал квакин     а к
# ----------------------
#    а ты  ты поедешь с нами    с тревогой переспросила она
#      у меня экзамены вступительные с завт
# ----------------------
#     папа  как насчет сказки    спросил кристофер робин
#          что насчет сказки    спросил папа
# ----------------------
#   вот это хорошо  как ты думаешь  много этому барашку надо травы
#        а что
#        ведь у меня д
# ----------------------
# где то с середины июня и до середины сентября я начинаю  что называется  жить в лесу  я перестаю быт
# ----------------------
#    наши вышли к границам румынии
#       читали    крым освобожден полностью
#       первая руда пришл
# ----------------------
#   наличка есть    резко осведомился таксист
#   ну да  конечно  но больших сумм с собой не вожу    сп
# ----------------------
#    ты что делаешь  как ты смеешь  ты зачем нашу морковку рвешь
#    перестань  тебе говорят
#    мальч
# ----------------------
#    голенищами
#       нищие     обрадовалась таинька     музыканты пришли  таинька захрустела крахмал
# ----------------------
#   ничего    сказал ему долгов    ничего  все будет нормально  как тебя зовут    андрей    сколько те
# ----------------------
#   ты откуда такая выскочила  босиком    засмеялся он
#   извините  я ошиблась    пролепетала я  вгляд
# ----------------------
#   милый  поцелуй мне ручку
#   перебери мои пальчики    смеется она
#   что это
#   протез  дорогой
#
# ----------------------
# год 1994 й по восточному календарю    год собаки  по
# решению юнеско он признан годом семьи
# поэтому
# ----------------------
# во время прогулки по городу муж засмотрелся на женщину  одетую в изящное кожаное пальто
# жена тут же
# ----------------------
# некий человек по имени ператин со слезами сказал своему сыну и соседям   в саду у меня растет дерево
# ----------------------
# у одного актера была уродливая жена  однажды в дождливый  пасмурный день она спросила его   как нам
# ----------------------
# жена спрашивает мужа
#    почему ты не носишь обручальное кольцо
#    в такую жару
#
# ----------------------
#
# алло  это милиция
#    нет  это квартира  но я могу позвать к телефону жену
#
# жена сообщает мужу
#
# ----------------------
# муж и жена обсуждают свой бюджет  все до последнего цента уходит на жизнь  а им хотелось бы немного
# ----------------------
#   снова наш чудесный сыночек вытащил деньги из моего бумажника    сердито заметил отец
#    почему ты
# ----------------------
# расстроенный муж говорит жене
#    мы сидим совершенно без денег  а должны срочно  заплатить по счета
# ----------------------
# муж возвращается с работы и видит  что жена плачет
#    я испекла тебе пирожки с мясом  но когда вышл
# ----------------------
#  этого супа можно было сварить литров сто    говорит муж жене
#    он так тебе понравился
#    нет  пр
# ----------------------
# жена с мужем и шестилетним сыном переходят вброд речку  посреди реки  когда вода уже была по грудь
# ----------------------
#  вы счастливы в семейной жизни
#    о да  мы так сильно любим друг друга  что уже три раза
# откладывал
# ----------------------
# пожилая еврейская пара готовится ко сну
#    изя  ты закрыл калитку
#    закрыл  соня  закрыл
#    а дв
# ----------------------
# муж и жена на прогулке беседуют
#    какая была анна каренина  вот это женщина  какие чувства  какая
# ----------------------
# ночь  супружеская спальня  жена  засыпая  сладко улыбается   интересно  помнит ли муженек  что завтр
# ----------------------
#   современная молодежь ужасно одевается  например вот этот парень
#    это    моя дочь
#    простите
# ----------------------
# к мужчине пришли друзья  хозяин только рукой махнул    жена с тещей сразу стол накрывают  выпивку ст
# ----------------------
# приходит после отпуска трудяга на работу и хвалится
#    прекрасно отдохнул
#    наверное  на море езд
# ----------------------
# муж говорит жене
#    ну и идиотка же ты
#    конечно  идиотка  была бы я за генералом замужем  была б
# ----------------------
# жена говорит мужу в гневе
#    лучше бы я вышла замуж за черта
#    что ты  дорогая  браки между кровн
# ----------------------
# заключенный в тюремной камере рассказывает сокамерникам
#    эх  до чего же мы с женой приятно провод
# ----------------------
#   золотце  я приготовила к твоему дню рождения роскошный подарок
#    так покажи его мне
#    подожди
# ----------------------
# в купе поезда едут муж  жена и двое медиков  всю дорогу жена пилит мужа  не дает ему и слова сказать
# ----------------------
#   перестань петь  я из за тебя не могу уснуть
#    ладно  я подожду  пока ты заснешь
#
#
# ----------------------
#   почему ты не выставил за дверь кота     спрашивает жена рассеянного мужа
#    дорогая  я выставил
# ----------------------
# гольдберг умер в кафе от апоплексии  его знакомый берется известить об этом вдову возможно тактичнее
# ----------------------
# старая графиня    служанке
#    кто это там скрипит
#    это ваш муж скрипит зубами
#    но у него же н
# ----------------------

# %% [markdown]
# ## Coroutines

# %% [markdown]
# **3.**(2) От некоторого устройства в режиме реального времени приходят данные. Необходимо написать сопрограмму, которая вычисляет среднее, дисперсию, а также количество элементов в переданном наборе данных с устройства. Результаты работы сопрограмма должна выдавать при отправке соответствующих сигналов.

# %%
import numpy as np

class PrintAverage(Exception):
    pass

class PrintDispersion(Exception):
    pass

class PrintQuantity(Exception):
    pass

def coroutines():
    print("Starting coroutine")
    elem = []
    try:
        while True:
            try:
                a = yield
                elem.append(a)
            except PrintDispersion:
                yield np.var(elem)
            except PrintAverage:
                yield np.mean(elem)
            except PrintQuantity:
                yield len(elem)
    finally:
        print("Stop coroutine")

coroutine = coroutines()
next(coroutine)

for i in range(12):
    coroutine.send(i)
    if i%2 == 0:
        print("Average:", coroutine.throw(PrintAverage))
        next(coroutine)
    if i%3 == 0:
        print("Dispersion:", coroutine.throw(PrintDispersion))
        next(coroutine)
    if i%4 == 0:
        print("Quantity:", coroutine.throw(PrintQuantity))
        next(coroutine)
        
coroutine.close()
# Out:
# Starting coroutine
# Average: 0.0
# Dispersion: 0.0
# Quantity: 1
# Average: 1.0
# Dispersion: 1.25
# Average: 2.0
# Quantity: 5
# Average: 3.0
# Dispersion: 4.0
# Average: 4.0
# Quantity: 9
# Dispersion: 8.25
# Average: 5.0
# Stop coroutine

# %% [markdown]
# **4.** (4) Представьте, что у вас настроено взаимодействие с сервером, от которого приходят пакеты, содержащие сообщения от различных клиентов. Обработка каждого из клиентов должна идти в отдельном потоке.
#
# Реализуйте:
#
# - (**i.**)  Корутину `connect_user`, которая принимает данные авторизации от пользователя, открывает файл с расширением `.txt` и создает на его основе корутину `write_to_file`.
# - (**ii.**)   Корутину `write_to_file(f_obj)`, которая записывает переданное планировщиком задач сообщение пользователя в файловый объект, переданный в качестве аргумента при генерации. Также корутина принимает и обрабатывает сигнал об окончании соединения и выходит из сопрограммы.
# - (**iii.**)  Планировщик задач, распределяющий задачи по сопроцессам на каждого пользователя.

# %%
class Terminate(Exception):
    pass 

class Connect(Exception):
    pass

def connect_user(username):
    with open('message.txt','w', encoding='utf-8') as f:
        yield from write_to_file(f)

def write_to_file(f_obj):
    while True:
        try:
            a = yield
            f_obj.writelines(a)
            f_obj.writelines('\n')
        except Terminate:
            print('finish')
            break
    f_obj.close()
    
def plan():
    user = []
    while True:
        try:
            username = yield
            user.append(username)
        except Connect:
            yield from connect_user(user)
            
 

coroutine = plan()
next(coroutine)
coroutine.throw(Connect)
coroutine.send('hello')
coroutine.send('Hi!')
coroutine.throw(Terminate)
coroutine.close()
# Out:
# finish
